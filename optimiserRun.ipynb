# %%
import optimiserBank

# %%
bounds = [(-5,5), (-5,5)] #bounds for each dimension (x and y)

PSO = optimiserBank.TS_DDEO(bounds, 15)

PSO.stage1()
# Out:
# Generation 200: Best RBF Fitness = [2.17695375]
# Iteration 2: Best Fitness = 0.9017043400862375
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 5
#       1 bounds = [(-5,5), (-5,5)] #bounds for each dimension (x and y)
#       3 PSO = optimiserBank.TS_DDEO(bounds, 15)
# ----> 5 PSO.stage1()
#
# File ~/projects/benchmarkingOptimisers/optimiserBank.py:356, in stage1(self)
#     352 iteration = 1
#     354 while len(self.feFeatures) < (self.pop_size + self.max_generations):
#     355     # Train surrogate model and find a solution
# --> 356     GPModel = GPTrain(self.feFeatures, self.feTargets, meanPrior='zero')
#     357     globalDE = DifferentialEvolution(self.globalBounds, GPModel)
#     358     bestGPSolution, bestGPFitness = globalDE.optimize()
#
# File ~/projects/benchmarkingOptimisers/optimiserBank.py:211, in optimize(self)
# ...
